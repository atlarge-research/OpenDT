# %%
import pandas as pd

# %%
simulation = pd.read_parquet("simulation.parquet")
validation = pd.read_parquet("validation.parquet")
simulation_30 = pd.read_parquet("simulation_30.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 simulation = pd.read_parquet("simulation.parquet")
#       2 validation = pd.read_parquet("validation.parquet")
# ----> 3 simulation_30 = pd.read_parquet("simulation_30.parquet")
#
# File /Library/Python/3.9/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
simulation
# Out:
#       power_draw  energy_usage  cpu_usage  cpu_utilization host_name  \
# 0      32.165581   9610.521484   447594.0         0.048091       H01
# 1      31.752739   9556.804688   421806.0         0.045320       H01
# 2      31.713406   9516.906250   419349.0         0.045056       H01
# 3      31.572540   9534.303711   410550.0         0.044111       H01
# 4      31.469666   9447.032227   404124.0         0.043421       H01
# ...          ...           ...        ...              ...       ...
# 8648   36.230137  10520.837891   701484.0         0.075370       H01
# 8649   36.016655  10946.159180   688149.0         0.073937       H01
# 8650   35.319057  10652.760742   644574.0         0.069255       H01
# 8651   35.313004  10613.628906   644196.0         0.069215       H01
# 8652   35.313004      0.000000   644196.0         0.069215       H01
#
#      cluster_name   timestamp  timestamp_absolute
# 0             C01      300000       1664575500000
# ...

# %%
validation
# Out:
#               timestamp-date-time    host  power_draw  energy_usage  timestamp
# 0       2022-10-11 16:05:30+02:00  r27n18        44.0        1320.0      30000
# 1       2022-10-11 16:06:00+02:00  r27n18        44.0        1320.0      60000
# 2       2022-10-11 16:06:30+02:00  r27n18        44.0        1320.0      90000
# 3       2022-10-11 16:07:00+02:00  r27n18        44.0        1320.0     120000
# 4       2022-10-11 16:07:30+02:00  r27n18        44.0        1320.0     150000
# ...                           ...     ...         ...           ...        ...
# 3260563 2022-10-09 21:36:00+02:00   r27n9        32.0         960.0 -152940000
# 3260564 2022-10-12 05:08:00+02:00   r27n9        32.0         960.0   46980000
# 3260565 2022-10-12 02:00:00+02:00   r27n9        32.0         960.0   35700000
# 3260566 2022-10-09 03:33:00+02:00   r27n9        32.0         960.0 -217920000
# 3260567 2022-10-10 03:52:30+02:00   r27n9        32.0         960.0 -130350000
#
# ...
